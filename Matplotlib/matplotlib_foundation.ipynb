# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
arr_x = np.random.randint(1,10,size=[1,10])
arr_y = np.random.randint(1,10,size=[1,10])

# %%
print(arr_x)
print(arr_y)
plt.scatter(arr_x,arr_y, c='red', s=50 , marker='o')
# Out:
# [[9 1 6 7 7 4 2 1 5 7]]
# [[1 3 3 3 6 8 5 8 7 1]]

# %%
# Now Let's Check line 
x_year = np.arange(2003,2025)
y_weight = np.random.randint(90,100,size=len(x_year))

# %%
print(x_year)
print(y_weight)
plt.plot(x_year,y_weight)
# Out:
# [2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016
#  2017 2018 2019 2020 2021 2022 2023 2024]
# [95 99 98 97 90 90 92 97 96 95 92 99 99 92 95 97 97 99 92 90 98 98]
