# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("./data/olympics-data.xlsx").head(500)
olm = df.head(200)

# %%
df.tail(10)
# Out:
#         athlete_id                   name   born_date           born_city  \
# 145490      149217            Sin Ye-Chan  1995-06-13                 NaN
# 145491      149218          Matthew Wepke  1989-12-05                 NaN
# 145492      149219  Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova  1998-08-31    Dva Polya Artash
# 145494      149221          George Wright  1890-07-21             Toronto
# 145495      149222      Polina Luchnikova  2002-01-30               Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20     Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08              Kotlas
# 145498      149225         André Foussard  1899-05-19               Niort
# 145499      149814          Bill Phillips  1913-07-15        Dulwich Hill
#
#                  born_region born_country                NOC  height_cm  \
# 145490                   NaN          NaN  Republic of Korea        NaN
# ...

# %%
df[df['NOC'].isin(['Australia','France'])]
# Out:
#         athlete_id                   name   born_date         born_city  \
# 0                1  Jean-François Blanchy  1886-12-12          Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01            Meulan
# 2                3           Jean Borotra  1898-08-13          Biarritz
# 3                4        Jacques Brugnon  1895-05-11       Paris VIIIe
# 4                5           Albert Canet  1878-04-17        Wandsworth
# ...            ...                    ...         ...               ...
# 144647      148343      Léo Le Blé Jaques  1997-01-02   Chêne-Bougeries
# 144648      148344            Liam Tourki  1999-03-25          Grenoble
# 144649      148345      Gwendoline Daudet  1998-11-28  Nogent-sur-Marne
# 145498      149225         André Foussard  1899-05-19             Niort
# 145499      149814          Bill Phillips  1913-07-15      Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
df[df['NOC'] == 'Australia']
# Out:
#         athlete_id               name   born_date     born_city  \
# 291            292      Maureen Adams  1937-08-27           NaN
# 292            293     Deonne Bridger  1972-05-15         Perth
# 293            294      Terry Donovan  1944-12-27           NaN
# 294            295   Myfanwy Matthews  1975-12-29         Dubbo
# 295            296         Carole Toy  1948-07-18           NaN
# ...            ...                ...         ...           ...
# 144154      147832       Adam Dickson  1995-12-01     Jindabyne
# 144155      147833   Valentino Guseli  2005-04-01      Canberra
# 144156      147834  Nicholas Timmings  1990-12-29        Gwelup
# 144157      147835      Brendan Corey  1997-01-21   Fredericton
# 145499      149814      Bill Phillips  1913-07-15  Dulwich Hill
#
#                          born_region born_country        NOC  height_cm  \
# 291                              NaN          NaN  Australia      169.0
# ...

# %%
df[df['name'].str.contains("Phillips")].head(10)
# Out:
#        athlete_id                name   born_date     born_city   born_region  \
# 10990       11047      Traci Phillips  1962-08-01      Honolulu       Hawaiʻi
# 12496       12565       Mark Phillips  1948-09-22   Cirencester       England
# 13120       13199    Merilyn Phillips  1957-03-19           NaN           NaN
# 13121       13200      Sarah Phillips  1967-07-03    Stonehaven      Scotland
# 18712       18840  Frederick Phillips  1884-03-13       Newport         Wales
# 19094       19228        Joe Phillips  1911-03-24           NaN           NaN
# 19095       19229      V. J. Phillips  1950-09-01           NaN           NaN
# 20314       20458     Brenda Phillips  1958-01-18           NaN           NaN
# 29930       30156   W. Lloyd Phillips  1881-09-08       Newport         Wales
# 31164       31400       Chet Phillips  1913-10-23  Philadelphia  Pennsylvania
#
#       born_country             NOC  height_cm  weight_kg   died_date
# ...

# %%
df[(df['weight_kg'] > 140) & (df['weight_kg'] < 150)].head()
# Out:
#        athlete_id                  name   born_date born_city  born_region  \
# 6420         6451         Jānis Krūmiņš  1930-01-30     Cēsis  Cēsu novads
# 32999       33249        Beáta Maksymow  1967-07-27   Czeladź      Śląskie
# 33747       34009         Liu Shenggang  1976-11-15       NaN          NaN
# 34049       34313         Hitoshi Saito  1961-01-02    Aomori       Aomori
# 34105       34369  Oswaldo Simões Filho  1952-10-12    Recife   Pernambuco
#
#       born_country                         NOC  height_cm  weight_kg  \
# 6420           LAT                Soviet Union      218.0      141.0
# 32999          POL                      Poland      180.0      145.0
# 33747          NaN  People's Republic of China      205.0      145.0
# 34049          JPN                       Japan      180.0      143.0
# 34105          BRA                      Brazil      187.0      144.0
#
#         died_date
# 6420   1994-11-20
# 32999         NaN
# 33747         NaN
# 34049  2015-01-20
# ...

# %%
df[(df['weight_kg'] > 140) & (df['weight_kg'] < 150)].sort_values(['NOC','name'],ascending=True)
# Out:
#         athlete_id                    name   born_date         born_city  \
# 129795      132439            Gor Minasyan  1994-10-25            Gyumri
# 54747        55141      Charles Garzarella  1964-09-10               NaN
# 103659      104648        Matthias Steiner  1982-08-25     Wien (Vienna)
# 104697      105719  Aliaksandr Malashevich  1977-04-07           Smarhon
# 119193      120984        Yauhen Zharnasek  1987-08-09            Lepiel
# 64894        65384        Zlatan Saračević  1956-07-27            Zenica
# 91507        92236        Daniel Hernandes  1979-04-16         São Paulo
# 34105        34369    Oswaldo Simões Filho  1952-10-12            Recife
# 56366        56767          Bohuslav Braum  1956-02-22    Praha (Prague)
# 86094        86780           Joachim Olsen  1977-05-31           Aalborg
# 69292        69810      Hans-Jürgen Jacobi  1950-07-26   Bad Langensalza
# 130856      133606           Ahmed Mohamed  1988-04-27         Beni Suef
# ...

# %%
olm.sample(10)
# Out:
#      athlete_id                      name   born_date  \
# 198         199             Chan Kong Wah  1961-08-31
# 56           57  Dorothy Lambert Chambers  1878-09-03
# 27           28        Guy, Baron Lejeune         NaN
# 187         188             Ronald Agénor  1964-11-13
# 168         169        Christina Papadaki  1973-02-24
# 32           33          Stéphane Renault  1968-03-01
# 49           50            Gillian Gowers  1964-04-09
# 10           11   Élie, Comte de Lastours  1874-08-12
# 1             2            Arnaud Boetsch  1969-04-01
# 185         186       Avgoustos Zerlentis  1886-11-05
#
#                        born_city         born_region born_country  \
# 198                          NaN                 NaN          NaN
# 56                        Ealing             England          GBR
# 27                           NaN                 NaN          NaN
# 187                        Rabat  Rabat-Salé-Kénitra          MAR
# ...

# %%
olm.set_index('athlete_id',inplace=True)
olm
# Out:
#                              name   born_date    born_city  \
# athlete_id
# 1           Jean-François Blanchy  1886-12-12     Bordeaux
# 2                  Arnaud Boetsch  1969-04-01       Meulan
# 3                    Jean Borotra  1898-08-13     Biarritz
# 4                 Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                    Albert Canet  1878-04-17   Wandsworth
# ...                           ...         ...          ...
# 196                 Chan Kin Ngai  1968-11-18          NaN
# 197                Chan Siu Kwong  1966-05-30          NaN
# 198                 Chan Chi Ming  1964-05-28          NaN
# 199                 Chan Kong Wah  1961-08-31          NaN
# 200                        Tim He  1962-04-14          NaN
#
#                      born_region born_country               NOC  height_cm  \
# athlete_id
# 1                        Gironde          FRA            France        NaN
# 2                       Yvelines          FRA            France      183.0
# ...

# %%
olm.reset_index(inplace=True)

# %%
olm.head()
# Out:
#                              athlete_id                   name   born_date  \
# NOC    born_region
# France Gironde                        1  Jean-François Blanchy  1886-12-12
#        Yvelines                       2         Arnaud Boetsch  1969-04-01
#        Pyrénées-Atlantiques           3           Jean Borotra  1898-08-13
#        Paris                          4        Jacques Brugnon  1895-05-11
#        England                        5           Albert Canet  1878-04-17
#
#                                born_city born_country  height_cm  weight_kg  \
# NOC    born_region
# France Gironde                  Bordeaux          FRA        NaN        NaN
#        Yvelines                   Meulan          FRA      183.0       76.0
#        Pyrénées-Atlantiques     Biarritz          FRA      183.0       76.0
#        Paris                 Paris VIIIe          FRA      168.0       64.0
#        England                Wandsworth          GBR        NaN        NaN
#
# ...

# %%
pd.set_option("display.max.rows",200)

olm.set_index(["NOC","born_region"],inplace=True)
olm.sort_index()
olm.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 pd.set_option("display.max.rows",200)
# ----> 3 olm.set_index(["NOC","born_region"],inplace=True)
#       4 olm.sort_index()
#       5 olm.head()
#
# NameError: name 'olm' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ASUS\mycode\Data-Analysis-DOOR\Pandas\data\coffee.csv")
# r escape \n 
df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
df.groupby(["Day", 'Coffee Type']).agg({"Units Sold": ['mean', "max",'min']}).sort_values(by='Day')
# Out:
#                       Units Sold
#                             mean max min
# Day       Coffee Type
# Friday    Espresso          45.0  45  45
#           Latte             35.0  35  35
# Monday    Espresso          25.0  25  25
#           Latte             15.0  15  15
# Saturday  Espresso          45.0  45  45
#           Latte             35.0  35  35
# Sunday    Espresso          45.0  45  45
#           Latte             35.0  35  35
# Thursday  Espresso          40.0  40  40
#           Latte             30.0  30  30
# Tuesday   Espresso          30.0  30  30
#           Latte             20.0  20  20
# Wednesday Espresso          35.0  35  35
#           Latte             25.0  25  25

# %%
df.groupby(["Day","Coffee Type"]).describe()
# Out:
#                       Units Sold
#                            count  mean std   min   25%   50%   75%   max
# Day       Coffee Type
# Friday    Espresso           1.0  45.0 NaN  45.0  45.0  45.0  45.0  45.0
#           Latte              1.0  35.0 NaN  35.0  35.0  35.0  35.0  35.0
# Monday    Espresso           1.0  25.0 NaN  25.0  25.0  25.0  25.0  25.0
#           Latte              1.0  15.0 NaN  15.0  15.0  15.0  15.0  15.0
# Saturday  Espresso           1.0  45.0 NaN  45.0  45.0  45.0  45.0  45.0
#           Latte              1.0  35.0 NaN  35.0  35.0  35.0  35.0  35.0
# Sunday    Espresso           1.0  45.0 NaN  45.0  45.0  45.0  45.0  45.0
#           Latte              1.0  35.0 NaN  35.0  35.0  35.0  35.0  35.0
# Thursday  Espresso           1.0  40.0 NaN  40.0  40.0  40.0  40.0  40.0
#           Latte              1.0  30.0 NaN  30.0  30.0  30.0  30.0  30.0
# Tuesday   Espresso           1.0  30.0 NaN  30.0  30.0  30.0  30.0  30.0
# ...
